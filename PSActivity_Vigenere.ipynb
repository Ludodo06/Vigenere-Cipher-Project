# %% [markdown]
# **_TO GO TROUGH THIS ACTIVITY, PRESS SHIFT+ENTER_**

# %%
from utility import *

# %% [markdown]
# ### The Vigenère Cipher: The Mysterious Package
#
# *It is 5 pm, and the library clock strikes. You dont have time to finish the chapter on the Vigenère cipher that you see a mysterious package on the table in front of you. It was not here 5 seconds earlier. You open it and find a note inside. The note is written in strange characters and seems to be encrypted. You decide to take on the challenge and uncover what it hides.*

# %% [markdown]
# Here is the note:
# ***
# *KHOHGGCSXOQYSFBCDOWOQFRNKCETFRCEGIQJTUBRGCJUOGDOHGJTZFVYSSHDNWONRPNSCVCHOWUQHRUKQDHIIIZZXHPOOZIQOWFVDPGCGGEVY
# OCVSVHPPONKVSSNUGPGZOWEHYUKYUUQFOOHFKYUCQVSSVUGPNYFQYHCQWZIMDUEVYVVLFMWJLHMKKYSUQFEKCQMWSIQVSSGLNVMQDAEVYBUEF
# YWESSXLPYSPHTPBXLPRZCQGLZIQIEVYPCCUCQQQOVDAESHWJZIMDPOGUZKLHUJNLBWHVZGMLPRHBHKCVYDFDWHVRCWAKVWMXDPNSNKGHOPHUM
# SMLFPHBHOOOHFGOPOWVSSSRWERCGVSSMSCCYFLPRKUYGDWHJNPSUSQPHWRWWRHRVMINEGROSLPDIWKCUCWXPOQIPRLBSLILNYGCYRADBPRVXV
# WWNWNPHBRWRVNZJLHQHCWHBWJPGBRYECGHJLRVUQFUBWHZFIIVHVYQQYASFQFQBLNTSCQXLQUQVZFCQRPBMLXPAIRFEVYBHWOMKWACHWJLHC
# QYLFXHAPKBLESWMWJPPFLUDCZVQWWNXFPOHGVSSHPASSUUVHWNKRWSUVWCSZLNWGUQFOOHFGDKCWJEVYGCQTIGKWG*
# ***
# Are you able to decrypt it?

# %% [markdown]
# Here are some tools that can be helpful for you!
# Let's have a look at them:
#
# 1) if you have already found the key, you can directly try to decrypt the text using the function decrypt_vigenere; for example, if you think that the key is *ABC*, just replace the secret_key with your key!

# %%
secret_key = "cloud"
decrypt_vigenere(secret_key)
# Out:
# ...

# %% [markdown]
# 2. if you are struggling a bit, here is another tool that can be helpful

# %%
plot_letters_frequency_analysis(extract_characters(CIPHER,1,5))
# Out:
# dict_values([4, 1, 11, 1, 2, 7, 12, 2, 3, 10, 7, 0, 1, 7, 1, 11, 12, 4, 0, 1, 4, 14, 7, 2, 3, 0])

# %% [markdown]
# 3. Another tool: extract_characters.

# %%
extract_characters(CIPHER,1,3)
# Out:
# 'KHCOSCWFKTCITRJGHTVSNNNVOQUDIZPZOVGGYVHOVNPOHKUOFUVVPFHWMEVFJMYQKMISLMAYEWSPPPLZGIEPUQVEWIPULJBVMRHVFHCKMPNHHSFBOFPVSEGSCFRYWNUPRRVNRLICWOPBIYYDRVNPRVJQWWGYGLUUHIHQAQBTQQVCPLAFYWKCJCLHKEMPLCQNPGSAUHKSWZWQOGCEGTK'

# %% [markdown]
# 4. Last available tool: find_letters_in_string.

# %%
find_letters_in_string(CIPHER, "OHFG")
# Out:
# Found "OHFG" at positions [337, 612]
# 
